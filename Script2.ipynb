# %% [markdown]
# <a href="https://colab.research.google.com/github/rjtarazonas97/Curso_Pandas_Python2025/blob/main/Script2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

datos = pd.read_excel("/content/BD_anuario_2024.xlsx")

datos
# Out:
#     Unnamed: 0 No. DE ASPIRANTES POR ESTADO, NIVEL Y GÉNERO    Unnamed: 2  \
# 0          NaN                                          NaN  PREPARATORIA
# 1          NaN                                       ESTADO             H
# 2          NaN                               AGUASCALIENTES             9
# 3          NaN                              BAJA CALIFORNIA            12
# 4          NaN                          BAJA CALIFORNIA SUR             5
# 5          NaN                                     CAMPECHE            20
# 6          NaN                                      CHIAPAS           203
# 7          NaN                                    CHIHUAHUA            14
# 8          NaN                             CIUDAD DE MÉXICO           420
# 9          NaN                         COAHUILA DE ZARAGOZA            14
# 10         NaN                                       COLIMA           NaN
# 11         NaN                                      DURANGO            72
# ...

# %%
import pandas as pd

datos = pd.read_csv("/content/Agricultura_y_Desarrollo_Rural_-_Evaluación_Agrícola_Departamento_de_Bolívar._20250903.csv")

datos
# Out:
#       CodDpto Departamento CodMunicipio Municipio          Cultivo  Periodo  \
# 0          13      Bolívar       13,006      Achí         Aguacate     2016
# 1          13      Bolívar       13,006      Achí          AHUYAMA     2016
# 2          13      Bolívar       13,006      Achí          AHUYAMA     2016
# 3          13      Bolívar       13,006      Achí      Arroz Riego     2016
# 4          13      Bolívar       13,006      Achí      Arroz Riego     2016
# ...       ...          ...          ...       ...              ...      ...
# 2630       13      Bolívar       13,894  Zambrano           Tabaco     2020
# 2631       13      Bolívar       13,894  Zambrano          Patilla     2020
# 2632       13      Bolívar       13,894  Zambrano            Melón     2020
# 2633       13      Bolívar       13,894  Zambrano             Yuca     2020
# 2634       13      Bolívar       13,894  Zambrano  Palma de aceite     2020
#
# ...

# %%
import pandas as pd

datos = pd.read_json("https://www.datos.gov.co/api/v3/views/wsfk-9bhd/query.json")

datos

# Los datos no salen porque ya tiene mas de 1000 usaos en su api pero ese seri ael modo en jason

# %%
import pandas as pd

dataset = [
    {"Nombre completo": "Jesus Tarazona"},
    {"Nombre completo": "Jesus Tarazona"},
    {"Nombre completo": "Jesus Tarazona"},
    {"Nombre completo": "Jesus Tarazona"},
            ]
datos = pd.DataFrame(dataset)

datos
# Out:
#   Nombre completo
# 0  Jesus Tarazona
# 1  Jesus Tarazona
# 2  Jesus Tarazona
# 3  Jesus Tarazona

# %%
import pandas as pd

# este es el link de google sheets https://docs.google.com/spreadsheets/d/1kUdxp00g3ojfXx6MekAQ_6zuWE-vwEGATBt_BGzcS1I/edit?usp=sharing
# en la parte final cambiamos el edit en adelante por lo siguiente: export?format=csv de esta manera jalara la info desde google sheets

datos = pd.read_csv("https://docs.google.com/spreadsheets/d/1kUdxp00g3ojfXx6MekAQ_6zuWE-vwEGATBt_BGzcS1I/export?format=csv")

datos
# Out:
#   nombre  edad  año de nacimiento sexo nacionalidad  profesion
# 0  jesus    28               1997    m         peru  ingeniero
